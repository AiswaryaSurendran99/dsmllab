# %% [markdown]
# <a href="https://colab.research.google.com/github/AiswaryaSurendran99/dsmllab/blob/main/ass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as  sns
import plotly.express as exp

# %%
iris=pd.read_csv("/content/sample_data/iris.csv")
iris.head()

#to obtain the first 5 rows and to read the csv file
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.head()

#to obtain first 5 rows
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.tail()

#to obtain the last 5 rows
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris.shape

# to obtain number of rows and columns
# Out:
# (150, 5)

# %%
iris.info
# Out:
# <bound method DataFrame.info of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.isnull()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
iris[iris.duplicated()]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 142           5.8          2.7           5.1          1.9  Virginica

# %%
data=iris.drop_duplicates(subset="variety",)
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 50            7.0          3.2           4.7          1.4  Versicolor
# 100           6.3          3.3           6.0          2.5   Virginica

# %%
iris.value_counts("variety")
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# dtype: int64

# %%
plt.hist(iris['sepal.length'],align='right',color='green',edgecolor='black')

#histogram with sepal length
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(x=iris['variety'],y=iris['petal.length'])

#boxplot

# %%
plt.scatter(iris['sepal.length'],iris['petal.length'],)

#scatterplot
#plotted the sepal length and petal length of the iris

# %%
iris.plot(kind='scatter', x='petal.length',y='petal.width',color='green')

# %%
iris.plot(kind='scatter', x='sepal.length',y='sepal.width',color='blue')

# %%
sns.scatterplot(x=iris['sepal.length'],y=iris['petal.length'],hue=iris['variety'])

# %%
sns.pairplot(iris,hue='variety')

# %%
x=pd.plotting.andrews_curves(iris,'variety')
x.plot()
plt.show()

#andrew curve

# %%
sns.kdeplot(data=iris)

#density chart using seaborn

# %%
iris['sepal.length'].plot(kind='density')
plt.show()

#density curve using matpotlib

# %%
x=iris['sepal.length'].to_numpy()
y=iris['petal.length'].to_numpy()
z=iris['sepal.length'].to_numpy()
colors=np.random.rand(len(z))
plt.scatter(x,y,c=colors)
plt.show()

#bubble chart

# %%
pd.plotting.parallel_coordinates(iris.drop('sepal.width',axis=1),'variety')

#parallel chart
